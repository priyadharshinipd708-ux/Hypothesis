# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadharshinipd708-ux/Hypothesis/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
data = {
    'Feature 1': [2, 4, 6, 8, 10, 12],
    'Feature 2': [1, 3, 5, 7, 9, 11],
    'Class': ['A', 'A', 'A', 'B', 'B', 'B']
}
df = pd.DataFrame(data)
X = df[['Feature 1', 'Feature 2']]
Y = df['Class']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Predicted values:", Y_pred)
print("Accuracy:", accuracy)
# Out:
# Predicted values: ['B' 'B']
# Accuracy: 0.0
